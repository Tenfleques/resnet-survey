# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
# ms-python.python added
import os
try:
	os.chdir(os.path.join(os.getcwd(), '../../../..'))
	print(os.getcwd())
except:
	pass
# Out:
# /tf/tendai

# %%
import matplotlib as plt
import pandas as pd
import os

os.chdir("./huawei/resnet-survey/logs")
from results import *

# %%
data = read_logs()

# %%
test_summarised_df = prepare_summary_df(data.get("test"))

# %%
test_summarised_df
# Out:
#      time_val_mean  time_val_std  time_val_min  time_val_max  time_avg_mean  \
# 0           0.0189      0.044683         0.004         0.146         0.0275
# 1           0.0294      0.029557         0.017         0.113         0.0246
# 2           0.0269      0.025265         0.015         0.098         0.0227
# 3           0.0269      0.027882         0.015         0.106         0.0239
# 4           0.0175      0.032470         0.004         0.109         0.0234
# ..             ...           ...           ...           ...            ...
# 154         0.0237      0.029443         0.009         0.107         0.0229
# 155         0.0174      0.032305         0.004         0.108         0.0237
# 156         0.0256      0.027921         0.015         0.105         0.0228
# 157         0.0256      0.027573         0.014         0.104         0.0228
# 158         0.0266      0.027577         0.016         0.105         0.0238
#
# ...

# %%
train_summarised_df = prepare_summary_df(data.get("train"))

# %%
train_summarised_df.head()
# Out:
#    epoch_id_mean  epoch_id_std  epoch_id_min  epoch_id_max  iteration_mean  \
# 0            0.0           0.0           0.0           0.0           195.0
# 1            1.0           0.0           1.0           1.0           195.0
# 2            2.0           0.0           2.0           2.0           195.0
# 3            3.0           0.0           3.0           3.0           195.0
# 4            4.0           0.0           4.0           4.0           195.0
#
#    iteration_std  iteration_min  iteration_max  len_trainloader_mean  \
# 0     116.904519            0.0          390.0                 391.0
# 1     116.904519            0.0          390.0                 391.0
# 2     116.904519            0.0          390.0                 391.0
# 3     116.904519            0.0          390.0                 391.0
# 4     116.904519            0.0          390.0                 391.0
#
#    len_trainloader_std  ...  loss_avg_min  loss_avg_max  acc_val_mean  \
# ...

# %%
train_summarised_df.head()
# Out:
#    epoch_id_mean  epoch_id_std  epoch_id_min  epoch_id_max  iteration_mean  \
# 0            0.0           0.0           0.0           0.0           195.0
# 1            1.0           0.0           1.0           1.0           195.0
# 2            2.0           0.0           2.0           2.0           195.0
# 3            3.0           0.0           3.0           3.0           195.0
# 4            4.0           0.0           4.0           4.0           195.0
#
#    iteration_std  iteration_min  iteration_max  len_trainloader_mean  \
# 0     116.904519            0.0          390.0                 391.0
# 1     116.904519            0.0          390.0                 391.0
# 2     116.904519            0.0          390.0                 391.0
# 3     116.904519            0.0          390.0                 391.0
# 4     116.904519            0.0          390.0                 391.0
#
#    len_trainloader_std  ...  loss_avg_min  loss_avg_max  acc_val_mean  \
# ...

# %%
test_summarised_df.head()
# Out:
#    time_val_mean  time_val_std  time_val_min  time_val_max  time_avg_mean  \
# 0         0.0189      0.044683         0.004         0.146         0.0275
# 1         0.0294      0.029557         0.017         0.113         0.0246
# 2         0.0269      0.025265         0.015         0.098         0.0227
# 3         0.0269      0.027882         0.015         0.106         0.0239
# 4         0.0175      0.032470         0.004         0.109         0.0234
#
#    time_avg_std  time_avg_min  time_avg_max  loss_val_mean  loss_val_std  ...  \
# 0      0.041722         0.012         0.146        1.79394      0.149181  ...
# 1      0.031131         0.013         0.113        0.93843      0.084838  ...
# 2      0.026579         0.013         0.098        1.16671      0.173674  ...
# 3      0.028958         0.013         0.106        0.77774      0.075011  ...
# 4      0.030156         0.012         0.109        0.63916      0.110235  ...
#
# ...

# %%
train_summarised_df = prepare_summary_df(data.get("train"))

# %%
train_summarised_df.head()
# Out:
#    epoch_id_mean  epoch_id_std  epoch_id_min  epoch_id_max  iteration_mean  \
# 0            0.0           0.0           0.0           0.0           195.0
# 1            1.0           0.0           1.0           1.0           195.0
# 2            2.0           0.0           2.0           2.0           195.0
# 3            3.0           0.0           3.0           3.0           195.0
# 4            4.0           0.0           4.0           4.0           195.0
#
#    iteration_std  iteration_min  iteration_max  len_trainloader_mean  \
# 0     116.904519            0.0          390.0                 391.0
# 1     116.904519            0.0          390.0                 391.0
# 2     116.904519            0.0          390.0                 391.0
# 3     116.904519            0.0          390.0                 391.0
# 4     116.904519            0.0          390.0                 391.0
#
#    len_trainloader_std  ...  loss_avg_min  loss_avg_max  acc_val_mean  \
# ...

# %%
train_summarised_df.describe()
# Out:
#        epoch_id_mean  epoch_id_std  epoch_id_min  epoch_id_max  \
# count     160.000000         160.0    160.000000    160.000000
# mean       79.500000           0.0     79.500000     79.500000
# std        46.332134           0.0     46.332134     46.332134
# min         0.000000           0.0      0.000000      0.000000
# 25%        39.750000           0.0     39.750000     39.750000
# 50%        79.500000           0.0     79.500000     79.500000
# 75%       119.250000           0.0    119.250000    119.250000
# max       159.000000           0.0    159.000000    159.000000
#
#        iteration_mean  iteration_std  iteration_min  iteration_max  \
# count           160.0     160.000000          160.0          160.0
# mean            195.0     116.904519            0.0          390.0
# std               0.0       0.000000            0.0            0.0
# min             195.0     116.904519            0.0          390.0
# ...

# %%
test_summarised_df.describe()
# Out:
#        time_val_mean  time_val_std  time_val_min  time_val_max  time_avg_mean  \
# count     159.000000    159.000000    159.000000    159.000000     159.000000
# mean        0.024051      0.028782      0.011189      0.105390       0.023257
# std         0.003539      0.002510      0.004910      0.005708       0.000840
# min         0.014800      0.025265      0.004000      0.095000       0.021500
# 25%         0.021750      0.027064      0.005500      0.102000       0.022750
# 50%         0.025500      0.028269      0.013000      0.105000       0.023300
# 75%         0.026550      0.030218      0.015000      0.108000       0.023700
# max         0.030100      0.044683      0.017000      0.146000       0.027500
#
#        time_avg_std  time_avg_min  time_avg_max  loss_val_mean  loss_val_std  \
# count    159.000000    159.000000    159.000000     159.000000    159.000000
# mean       0.028950      0.012321      0.105390       0.444682      0.102306
# ...

# %%
train_summarised_df[["time_avg_mean", "time_val_mean"]].plot()

# %%
train_summarised_df[["loss_avg_mean", "acc_val_mean"]].plot()

# %%
train_summarised_df[["loss_avg_mean", "acc_avg_mean", "loss_val_mean", "acc_val_mean"]].plot()

# %%
train_summarised_df[["loss_avg_mean", "loss_val_mean"]].plot()

# %%
train_summarised_df[["acc_avg_mean", "acc_val_mean"]].plot()

# %%
test_summarised_df[["time_avg_mean", "time_val_mean"]].plot()

# %%
test_summarised_df[["loss_avg_mean", "loss_val_mean"]].plot()

# %%
test_summarised_df[["acc_avg_mean", "acc_val_mean"]].plot()

# %%
test_summarised_df[["loss_avg_mean", "acc_avg_mean", "loss_val_mean", "acc_val_mean"]].plot()
