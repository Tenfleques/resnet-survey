# %%
import reports as rp
import pandas as pd

# %%
data_dict = rp.run()

# %%
df = pd.DataFrame(data_dict)
df["prec"] = df["prec"].astype(float)
df["lr"] = df["lr"].astype(float)
df["train_avg_loss"] = df["train_avg_loss"].astype(float)
df["test_avg_loss"] = df["test_avg_loss"].astype(float)
df["test_val_loss"] = df["test_val_loss"].astype(float)
df["tds"] = df["tds"].astype(float)

df["cifar"] = df["cifar"].astype(int)
df["layer"] = df["layer"].astype(int)
df["epochs"] = df["epochs"].astype(int)
df["minibatch"] = df["minibatch"].astype(int)
df["sc"] = df["sc"].astype(int)
df["rb"] = df["rb"].astype(int)

df["rb"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# drop incorrect log, added for use in creating chart comparison

# %%
df = df[ ~(((df["layer"] ==50) | (df["layer"] == 62)) & (df[""].isnull())) ]
df
# Out:
#                            name  cifar  layer  epochs  minibatch    lr  rb  \
# 0             resnet20-cifar-10     10     20     160        128  0.10  -1
# 1      resnet20-cifar-10-lr-.01     10     20     160        128  0.01  -1
# 2      resnet20-cifar-10-lr-.02     10     20     160        128  0.02  -1
# 3       resnet20-cifar-10-lr-.2     10     20     160        128  0.20  -1
# 4       resnet20-cifar-10-lr-.5     10     20     160        128  0.50  -1
# ..                          ...    ...    ...     ...        ...   ...  ..
# 69     resnet110-cifar-100-rb-3    100    110     160        128  0.10   3
# 70     resnet110-cifar-100-sc-1    100    110     160        128  0.10  -1
# 71     resnet110-cifar-100-sc-3    100    110     160        128  0.10  -1
# 72  resnet110-cifar-100-tds-0.5    100    110     160        128  0.10  -1
# 73  resnet110-cifar-100-tds-0.2    100    110     160        128  0.10  -1
#
#     sc  tds   prec  train_avg_loss  train_val_loss  test_avg_loss  \
# ...

# %%
df_c_10 = df[df["cifar"] == 10]
df_c_10.drop(["name","cifar"], axis=1).sort_values(by="prec", ascending=False)
# Out:
#     layer  epochs  minibatch    lr  rb  sc  tds   prec  train_avg_loss  \
# 56    110     160         64  0.10  -1  -1  1.0  94.03        0.214399
# 51    110     160        128  0.20  -1  -1  1.0  94.00        0.239813
# 27     56     160        128  0.20  -1  -1  1.0  93.86        0.217774
# 48    110     160        128  0.10  -1  -1  1.0  93.64        0.185127
# 55    110     320        128  0.10  -1  -1  1.0  93.45        0.091158
# 45     62     160        128  0.10  -1  -1  1.0  93.38        0.168845
# 32     56     160         64  0.10  -1  -1  1.0  93.38        0.223451
# 24     56     160        128  0.10  -1  -1  1.0  93.23        0.168009
# 21     50     160        128  0.10  -1  -1  1.0  93.15        0.167530
# 31     56     320        128  0.10  -1  -1  1.0  93.05        0.087030
# 28     56     160        128  0.50  -1  -1  1.0  92.94        0.368743
# 33     56     160        256  0.10  -1  -1  1.0  92.59        0.174516
# ...

# %%
df_c_100 = df[df["cifar"] == 100]
df_c_100.drop(["name","cifar"], axis=1).sort_values(by="prec", ascending=False)
# Out:
#     layer  epochs  minibatch    lr  rb  sc  tds   prec  train_avg_loss  \
# 66    110     160         64  0.10  -1  -1  1.0  72.34        0.714020
# 58    110     160        128  0.10  -1  -1  1.0  72.14        0.607312
# 61    110     160        128  0.20  -1  -1  1.0  71.97        0.752711
# 69    110     160        128  0.10   3  -1  1.0  71.86        0.603380
# 73    110     160        128  0.10  -1  -1  0.2  71.70        0.652055
# 68    110     160        128  0.10   2  -1  1.0  71.45        0.580149
# 72    110     160        128  0.10  -1  -1  0.5  71.39        0.613704
# 65    110     320        128  0.10  -1  -1  1.0  71.38        0.312704
# 70    110     160        128  0.10  -1   1  1.0  71.21        0.598155
# 62    110     160        128  0.50  -1  -1  1.0  71.18        1.162117
# 71    110     160        128  0.10  -1   3  1.0  70.84        0.606740
# 42     56     160         64  0.10  -1  -1  1.0  70.80        0.766951
# ...

# %% [markdown]
# ## Report on CIFAR-10

# %% [markdown]
# sort by precision to see the precision performance

# %%
df_c_10.sort_values(by=["minibatch"], ascending=False).sort_values(by=["prec"], ascending=False).head(15)
# Out:
#                                  name  cifar  layer  epochs  minibatch   lr  \
# 56   resnet110-cifar-10-mini-batch-64     10    110     160         64  0.1
# 51           resnet110-cifar-10-lr-.2     10    110     160        128  0.2
# 27            resnet56-cifar-10-lr-.2     10     56     160        128  0.2
# 48                 resnet110-cifar-10     10    110     160        128  0.1
# 55      resnet110-cifar-10-epochs-320     10    110     320        128  0.1
# 32    resnet56-cifar-10-mini-batch-64     10     56     160         64  0.1
# 45              resnet62-cifar-10-l62     10     62     160        128  0.1
# 24                  resnet56-cifar-10     10     56     160        128  0.1
# 21              resnet50-cifar-10-l50     10     50     160        128  0.1
# 31       resnet56-cifar-10-epochs-320     10     56     320        128  0.1
# 28            resnet56-cifar-10-lr-.5     10     56     160        128  0.5
# ...

# %%
df_c_10.sort_values(by="prec").plot.bar(x="minibatch", y="prec", rot=75, ylim=[84,94.5], figsize=(15, 5))

# %% [markdown]
#  `for CIFAR-10, adjusting the batch size to 64 produced better precision`

# %% [markdown]
# #### compare across leaning rate

# %%
df_c_10.sort_values(by=["layer", "lr"], ascending=False).plot.bar(x="lr", y="prec", rot=75, ylim=[84,94.5], figsize=(15, 5))

# %% [markdown]
# #### compare across number of epochs

# %%
df_c_10.sort_values(by=["prec", "epochs"], ascending=False).plot.bar(x="epochs", y="prec", rot=75, ylim=[84,94.5], figsize=(15, 5))

# %%
df_c_10.sort_values(by="test_val_loss", ascending=True).head()
# Out:
#                                 name  cifar  layer  epochs  minibatch   lr  \
# 31      resnet56-cifar-10-epochs-320     10     56     320        128  0.1
# 55     resnet110-cifar-10-epochs-320     10    110     320        128  0.1
# 21             resnet50-cifar-10-l50     10     50     160        128  0.1
# 7       resnet20-cifar-10-epochs-320     10     20     320        128  0.1
# 56  resnet110-cifar-10-mini-batch-64     10    110     160         64  0.1
#
#     rb  sc  tds   prec  train_avg_loss  train_val_loss  test_avg_loss  \
# 31  -1  -1  1.0  93.05        0.087030        0.087088       0.366807
# 55  -1  -1  1.0  93.45        0.091158        0.090429       0.371125
# 21  -1  -1  1.0  93.15        0.167530        0.167957       0.392484
# 7   -1  -1  1.0  91.71        0.105918        0.106472       0.401427
# 56  -1  -1  1.0  94.03        0.214399        0.213416       0.404220
#
#     test_val_loss
# 31       0.366807  NaN
# 55       0.371125  NaN
# 21       0.392484  l50
# ...

# %% [markdown]
# ### check the progression of perfomance and loss with changes in layers

# %%
base_10_filter = (df_c_10["epochs"] == 160) & (df_c_10["minibatch"] == 128) & (df_c_10["lr"] == 0.1)
base_10_df = df_c_10[base_10_filter]
base_10_df[["layer","prec"]]
# Out:
#     layer   prec
# 0      20  91.37
# 21     50  93.15
# 24     56  93.23
# 45     62  93.38
# 48    110  93.64

# %%
base_10_df.plot.bar(x="layer", y="prec", rot=0, ylim=[91,94])

# %%
base_10_df.plot.bar(x="layer", y=["test_val_loss"], rot=0, ylim=[.35,.45])

# %%
df_c_10.sort_values(by="test_val_loss", ascending=True).head(10)
# Out:
#                                 name  cifar  layer epochs minibatch   lr  rb  \
# 31      resnet56-cifar-10-epochs-320     10     56    320       128  0.1  -1
# 55     resnet110-cifar-10-epochs-320     10    110    320       128  0.1  -1
# 21             resnet50-cifar-10-l50     10     50    160       128  0.1  -1
# 7       resnet20-cifar-10-epochs-320     10     20    320       128  0.1  -1
# 56  resnet110-cifar-10-mini-batch-64     10    110    160        64  0.1  -1
# 24                 resnet56-cifar-10     10     56    160       128  0.1  -1
# 45             resnet62-cifar-10-l62     10     62    160       128  0.1  -1
# 32   resnet56-cifar-10-mini-batch-64     10     56    160        64  0.1  -1
# 8    resnet20-cifar-10-mini-batch-64     10     20    160        64  0.1  -1
# 48                resnet110-cifar-10     10    110    160       128  0.1  -1
#
#     sc tds   prec  train_avg_loss  train_val_loss  test_avg_loss  \
# ...

# %%
df_c_10.sort_values(by="test_avg_loss", ascending=True).head(10)
# Out:
#                                 name  cifar  layer epochs minibatch   lr  rb  \
# 31      resnet56-cifar-10-epochs-320     10     56    320       128  0.1  -1
# 55     resnet110-cifar-10-epochs-320     10    110    320       128  0.1  -1
# 21             resnet50-cifar-10-l50     10     50    160       128  0.1  -1
# 7       resnet20-cifar-10-epochs-320     10     20    320       128  0.1  -1
# 56  resnet110-cifar-10-mini-batch-64     10    110    160        64  0.1  -1
# 20                 resnet50-cifar-10     10     50    160       128  0.1  -1
# 44                 resnet62-cifar-10     10     62    160       128  0.1  -1
# 24                 resnet56-cifar-10     10     56    160       128  0.1  -1
# 45             resnet62-cifar-10-l62     10     62    160       128  0.1  -1
# 32   resnet56-cifar-10-mini-batch-64     10     56    160        64  0.1  -1
#
#     sc tds   prec  train_avg_loss  train_val_loss  test_avg_loss  \
# ...

# %% [markdown]
# ## Report on CIFAR-100

# %%
df_c_100.sort_values(by="prec", ascending=False).head(10)
# Out:
#                                  name  cifar  layer  epochs  minibatch   lr  \
# 66  resnet110-cifar-100-mini-batch-64    100    110     160         64  0.1
# 58                resnet110-cifar-100    100    110     160        128  0.1
# 61          resnet110-cifar-100-lr-.2    100    110     160        128  0.2
# 69           resnet110-cifar-100-rb-3    100    110     160        128  0.1
# 73        resnet110-cifar-100-tds-0.2    100    110     160        128  0.1
# 68           resnet110-cifar-100-rb-2    100    110     160        128  0.1
# 72        resnet110-cifar-100-tds-0.5    100    110     160        128  0.1
# 65     resnet110-cifar-100-epochs-320    100    110     320        128  0.1
# 70           resnet110-cifar-100-sc-1    100    110     160        128  0.1
# 62          resnet110-cifar-100-lr-.5    100    110     160        128  0.5
#
#     rb  sc  tds   prec  train_avg_loss  train_val_loss  test_avg_loss  \
# ...

# %%
df_c_100.sort_values(by=["minibatch"], ascending=False).sort_values(by=["prec"], ascending=False).head(15)
# Out:
#                                  name  cifar  layer  epochs  minibatch   lr  \
# 66  resnet110-cifar-100-mini-batch-64    100    110     160         64  0.1
# 58                resnet110-cifar-100    100    110     160        128  0.1
# 61          resnet110-cifar-100-lr-.2    100    110     160        128  0.2
# 69           resnet110-cifar-100-rb-3    100    110     160        128  0.1
# 73        resnet110-cifar-100-tds-0.2    100    110     160        128  0.1
# 68           resnet110-cifar-100-rb-2    100    110     160        128  0.1
# 72        resnet110-cifar-100-tds-0.5    100    110     160        128  0.1
# 65     resnet110-cifar-100-epochs-320    100    110     320        128  0.1
# 70           resnet110-cifar-100-sc-1    100    110     160        128  0.1
# 62          resnet110-cifar-100-lr-.5    100    110     160        128  0.5
# 71           resnet110-cifar-100-sc-3    100    110     160        128  0.1
# ...

# %%
df_c_100.sort_values(by="prec").plot.bar(x="minibatch", y="prec", rot=75, ylim=[57,73], figsize=(15, 5))

# %% [markdown]
#  `for CIFAR-100, adjusting the batch size to 64 produced better precision`

# %% [markdown]
# #### compare across leraning rate

# %%
df_c_100.sort_values(by=["layer", "lr"], ascending=False).plot.bar(x="lr", y="prec", rot=75, ylim=[57,73], figsize=(15, 5))

# %% [markdown]
# #### compare across number of epochs

# %%
df_c_100.sort_values(by=["prec", "epochs"], ascending=False).plot.bar(x="epochs", y="prec", rot=75, ylim=[56,73], figsize=(15, 5))

# %% [markdown]
# #### changes in residual blocks

# %%
filter_for_rb = ((df_c_100["minibatch"] == 128) 
        & (df_c_100["epochs"] == 160) 
        & (df_c_100["lr"] == 0.1) 
        & (df_c_100["layer"] == 110) 
        & (df_c_100["tds"] == 1.0) 
        & (df_c_100["sc"] == -1))
                    
df_c_100[filter_for_rb].sort_values(by=["rb"], ascending=False).plot.bar(x="rb", y="prec", rot=0, ylim=[70,73])

# %% [markdown]
# #### changes in skip connections

# %%
filter_for_rb = ((df_c_100["minibatch"] == 128) 
        & (df_c_100["epochs"] == 160) 
        & (df_c_100["lr"] == 0.1) 
        & (df_c_100["layer"] == 110) 
        & (df_c_100["tds"] == 1.0) 
        & (df_c_100["rb"] == -1))
                    
df_c_100[filter_for_rb].sort_values(by=["prec"], ascending=False).plot.bar(x="sc", y="prec", rot=0, ylim=[70,73])

# %% [markdown]
# ### check the progression of perfomance and loss with changes in layers

# %%
base_100_filter = (df_c_100["epochs"] == 160) & (df_c_100["minibatch"] == 128) & (df_c_100["lr"] == 0.1) & (df_c_100["rb"] == -1) & (df_c_100["sc"] == -1) & (df_c_100["tds"] == 1) 
base_100_df = df_c_100[base_100_filter]
base_100_df[["layer","prec"]]
# Out:
#     layer   prec
# 10     20  67.36
# 23     50  69.87
# 34     56  70.46
# 47     62  70.24
# 58    110  72.14

# %%
base_100_df.plot.bar(x="layer", y="prec", rot=0, ylim=[66,73])

# %%
base_100_df.plot.bar(x="layer", y=["test_val_loss"], rot=0, ylim=[1.6,1.72])

# %%
df_c_100.sort_values(by="test_val_loss", ascending=True).head(10)
# Out:
#                                  name  cifar  layer epochs minibatch   lr  rb  \
# 17      resnet20-cifar-100-epochs-320    100     20    320       128  0.1  -1
# 18   resnet20-cifar-100-mini-batch-64    100     20    160        64  0.1  -1
# 42   resnet56-cifar-100-mini-batch-64    100     56    160        64  0.1  -1
# 10                 resnet20-cifar-100    100     20    160       128  0.1  -1
# 66  resnet110-cifar-100-mini-batch-64    100    110    160        64  0.1  -1
# 41      resnet56-cifar-100-epochs-320    100     56    320       128  0.1  -1
# 34                 resnet56-cifar-100    100     56    160       128  0.1  -1
# 65     resnet110-cifar-100-epochs-320    100    110    320       128  0.1  -1
# 12          resnet20-cifar-100-lr-.02    100     20    160       128  .02  -1
# 13           resnet20-cifar-100-lr-.2    100     20    160       128   .2  -1
#
#     sc tds   prec  train_avg_loss  train_val_loss  test_avg_loss  \
# ...

# %%
df_c_100.sort_values(by="test_avg_loss", ascending=True).head(10)
# Out:
#                                  name  cifar  layer epochs minibatch   lr  rb  \
# 17      resnet20-cifar-100-epochs-320    100     20    320       128  0.1  -1
# 18   resnet20-cifar-100-mini-batch-64    100     20    160        64  0.1  -1
# 42   resnet56-cifar-100-mini-batch-64    100     56    160        64  0.1  -1
# 10                 resnet20-cifar-100    100     20    160       128  0.1  -1
# 66  resnet110-cifar-100-mini-batch-64    100    110    160        64  0.1  -1
# 41      resnet56-cifar-100-epochs-320    100     56    320       128  0.1  -1
# 34                 resnet56-cifar-100    100     56    160       128  0.1  -1
# 65     resnet110-cifar-100-epochs-320    100    110    320       128  0.1  -1
# 12          resnet20-cifar-100-lr-.02    100     20    160       128  .02  -1
# 13           resnet20-cifar-100-lr-.2    100     20    160       128   .2  -1
#
#     sc tds   prec  train_avg_loss  train_val_loss  test_avg_loss  \
# ...
