# %%
import reports as rp
import pandas as pd

# %%
data_dict = rp.run()

# %%
df = pd.DataFrame(data_dict)
df["prec"] = df["prec"].astype(float)

# %%
df_c_10 = df[df["cifar"] == 10]
df_c_10.drop(["name","cifar"], axis=1).sort_values(by="prec", ascending=False)
# Out:
#     layer epochs minibatch   lr  rb  sc tds   prec  train_avg_loss  \
# 56    110    160        64  0.1  -1  -1   1  94.03        0.214399
# 51    110    160       128   .2  -1  -1   1  94.00        0.239813
# 27     56    160       128   .2  -1  -1   1  93.86        0.217774
# 48    110    160       128  0.1  -1  -1   1  93.64        0.185127
# 55    110    320       128  0.1  -1  -1   1  93.45        0.091158
# 45     62    160       128  0.1  -1  -1   1  93.38        0.168845
# 32     56    160        64  0.1  -1  -1   1  93.38        0.223451
# 20     50    160       128  0.1  -1  -1   1  93.23        0.168009
# 44     62    160       128  0.1  -1  -1   1  93.23        0.168009
# 24     56    160       128  0.1  -1  -1   1  93.23        0.168009
# 21     50    160       128  0.1  -1  -1   1  93.15        0.167530
# 31     56    320       128  0.1  -1  -1   1  93.05        0.087030
# 28     56    160       128   .5  -1  -1   1  92.94        0.368743
# ...

# %%
df_c_100 = df[df["cifar"] == 100]
df_c_100.drop(["name","cifar"], axis=1).sort_values(by="prec", ascending=False)
# Out:
#     layer epochs minibatch   lr  rb  sc  tds   prec  train_avg_loss  \
# 66    110    160        64  0.1  -1  -1    1  72.34        0.714020
# 58    110    160       128  0.1  -1  -1    1  72.14        0.607312
# 61    110    160       128   .2  -1  -1    1  71.97        0.752711
# 69    110    160       128  0.1   3  -1    1  71.86        0.603380
# 73    110    160       128  0.1  -1  -1  0.2  71.70        0.652055
# 68    110    160       128  0.1   2  -1    1  71.45        0.580149
# 72    110    160       128  0.1  -1  -1  0.5  71.39        0.613704
# 65    110    320       128  0.1  -1  -1    1  71.38        0.312704
# 70    110    160       128  0.1  -1   1    1  71.21        0.598155
# 62    110    160       128   .5  -1  -1    1  71.18        1.162117
# 71    110    160       128  0.1  -1   3    1  70.84        0.606740
# 42     56    160        64  0.1  -1  -1    1  70.80        0.766951
# 37     56    160       128   .2  -1  -1    1  70.69        0.741960
# ...

# %% [markdown]
# ## Report on CIFAR-10

# %%
df_c_10.sort_values(by="prec", ascending=False).head(10)
# Out:
#                                 name  cifar  layer epochs minibatch   lr  rb  \
# 56  resnet110-cifar-10-mini-batch-64     10    110    160        64  0.1  -1
# 51          resnet110-cifar-10-lr-.2     10    110    160       128   .2  -1
# 27           resnet56-cifar-10-lr-.2     10     56    160       128   .2  -1
# 48                resnet110-cifar-10     10    110    160       128  0.1  -1
# 55     resnet110-cifar-10-epochs-320     10    110    320       128  0.1  -1
# 45             resnet62-cifar-10-l62     10     62    160       128  0.1  -1
# 32   resnet56-cifar-10-mini-batch-64     10     56    160        64  0.1  -1
# 20                 resnet50-cifar-10     10     50    160       128  0.1  -1
# 44                 resnet62-cifar-10     10     62    160       128  0.1  -1
# 24                 resnet56-cifar-10     10     56    160       128  0.1  -1
#
#     sc tds   prec  train_avg_loss  train_val_loss  test_avg_loss  \
# ...

# %%
df_c_10.sort_values(by="test_val_loss", ascending=True).head(10)
# Out:
#                                 name  cifar  layer epochs minibatch   lr  rb  \
# 31      resnet56-cifar-10-epochs-320     10     56    320       128  0.1  -1
# 55     resnet110-cifar-10-epochs-320     10    110    320       128  0.1  -1
# 21             resnet50-cifar-10-l50     10     50    160       128  0.1  -1
# 7       resnet20-cifar-10-epochs-320     10     20    320       128  0.1  -1
# 56  resnet110-cifar-10-mini-batch-64     10    110    160        64  0.1  -1
# 20                 resnet50-cifar-10     10     50    160       128  0.1  -1
# 44                 resnet62-cifar-10     10     62    160       128  0.1  -1
# 24                 resnet56-cifar-10     10     56    160       128  0.1  -1
# 45             resnet62-cifar-10-l62     10     62    160       128  0.1  -1
# 32   resnet56-cifar-10-mini-batch-64     10     56    160        64  0.1  -1
#
#     sc tds   prec  train_avg_loss  train_val_loss  test_avg_loss  \
# ...

# %%
df_c_10.sort_values(by="test_avg_loss", ascending=True).head(10)
# Out:
#                                 name  cifar  layer epochs minibatch   lr  rb  \
# 31      resnet56-cifar-10-epochs-320     10     56    320       128  0.1  -1
# 55     resnet110-cifar-10-epochs-320     10    110    320       128  0.1  -1
# 21             resnet50-cifar-10-l50     10     50    160       128  0.1  -1
# 7       resnet20-cifar-10-epochs-320     10     20    320       128  0.1  -1
# 56  resnet110-cifar-10-mini-batch-64     10    110    160        64  0.1  -1
# 20                 resnet50-cifar-10     10     50    160       128  0.1  -1
# 44                 resnet62-cifar-10     10     62    160       128  0.1  -1
# 24                 resnet56-cifar-10     10     56    160       128  0.1  -1
# 45             resnet62-cifar-10-l62     10     62    160       128  0.1  -1
# 32   resnet56-cifar-10-mini-batch-64     10     56    160        64  0.1  -1
#
#     sc tds   prec  train_avg_loss  train_val_loss  test_avg_loss  \
# ...

# %% [markdown]
# ## Report on CIFAR-100

# %%
df_c_100.sort_values(by="prec", ascending=False).head(10)
# Out:
#                                  name  cifar  layer epochs minibatch   lr  rb  \
# 66  resnet110-cifar-100-mini-batch-64    100    110    160        64  0.1  -1
# 58                resnet110-cifar-100    100    110    160       128  0.1  -1
# 61          resnet110-cifar-100-lr-.2    100    110    160       128   .2  -1
# 69           resnet110-cifar-100-rb-3    100    110    160       128  0.1   3
# 73        resnet110-cifar-100-tds-0.2    100    110    160       128  0.1  -1
# 68           resnet110-cifar-100-rb-2    100    110    160       128  0.1   2
# 72        resnet110-cifar-100-tds-0.5    100    110    160       128  0.1  -1
# 65     resnet110-cifar-100-epochs-320    100    110    320       128  0.1  -1
# 70           resnet110-cifar-100-sc-1    100    110    160       128  0.1  -1
# 62          resnet110-cifar-100-lr-.5    100    110    160       128   .5  -1
#
#     sc  tds   prec  train_avg_loss  train_val_loss  test_avg_loss  \
# ...

# %%
df_c_100.sort_values(by="test_val_loss", ascending=True).head(10)
# Out:
#                                  name  cifar  layer epochs minibatch   lr  rb  \
# 17      resnet20-cifar-100-epochs-320    100     20    320       128  0.1  -1
# 18   resnet20-cifar-100-mini-batch-64    100     20    160        64  0.1  -1
# 42   resnet56-cifar-100-mini-batch-64    100     56    160        64  0.1  -1
# 10                 resnet20-cifar-100    100     20    160       128  0.1  -1
# 66  resnet110-cifar-100-mini-batch-64    100    110    160        64  0.1  -1
# 41      resnet56-cifar-100-epochs-320    100     56    320       128  0.1  -1
# 46                 resnet62-cifar-100    100     62    160       128  0.1  -1
# 22                 resnet50-cifar-100    100     50    160       128  0.1  -1
# 34                 resnet56-cifar-100    100     56    160       128  0.1  -1
# 65     resnet110-cifar-100-epochs-320    100    110    320       128  0.1  -1
#
#     sc tds   prec  train_avg_loss  train_val_loss  test_avg_loss  \
# ...

# %%
df_c_100.sort_values(by="test_avg_loss", ascending=True).head(10)
# Out:
#                                  name  cifar  layer epochs minibatch   lr  rb  \
# 17      resnet20-cifar-100-epochs-320    100     20    320       128  0.1  -1
# 18   resnet20-cifar-100-mini-batch-64    100     20    160        64  0.1  -1
# 42   resnet56-cifar-100-mini-batch-64    100     56    160        64  0.1  -1
# 10                 resnet20-cifar-100    100     20    160       128  0.1  -1
# 66  resnet110-cifar-100-mini-batch-64    100    110    160        64  0.1  -1
# 41      resnet56-cifar-100-epochs-320    100     56    320       128  0.1  -1
# 46                 resnet62-cifar-100    100     62    160       128  0.1  -1
# 22                 resnet50-cifar-100    100     50    160       128  0.1  -1
# 34                 resnet56-cifar-100    100     56    160       128  0.1  -1
# 65     resnet110-cifar-100-epochs-320    100    110    320       128  0.1  -1
#
#     sc tds   prec  train_avg_loss  train_val_loss  test_avg_loss  \
# ...
